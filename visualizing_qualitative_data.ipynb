# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
listing = pd.read_csv('listings.csv')

# %%
listing
# Out:
#              id                                              name    host_id  \
# 0          3647               THE VILLAGE OF HARLEM....NEW YORK !       4632
# 1          3831                   Cozy Entire Floor of Brownstone       4869
# 2          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 3          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# 4          5121                                   BlissArtsSpace!       7356
# ...         ...                                               ...        ...
# 48372  38564068                                 Top Floor Delight  207204450
# 48373  38564524                             Central Park Elegance    1567562
# 48374  38566777                              Quiet room available  159902221
# 48375  38567542              Spacious room in Brooklyn brownstone   68905617
# 48376  38568081         Petrose home by JFK, Beach &St John Hosp.  293596932
#
# ...

# %%
sn.countplot(x = 'neighbourhood_group', data = listing)
plt.show()

# %%
sn.barplot(x = 'neighbourhood_group', y = 'price', data = listing)
plt.show()

# %%
sn.barplot(x = 'neighbourhood_group', y = 'price', data = listing)
plt.show()

# %%
sn.barplot(x = 'neighbourhood_group', y = 'price', data = listing, ci = False)
plt.show()
# Out:
# C:\Users\tebrick_KING\AppData\Local\Temp\ipykernel_16284\2391903325.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sn.barplot(x = 'neighbourhood_group', y = 'price', data = listing, ci = False)

# %%
sn.barplot(x='neighbourhood_group', y='price', data=listing)
plt.title("Average Price by Neighbourhood Group")
plt.xlabel("Neighbourhood Group")
plt.ylabel("Average Price")
plt.show()

# %%
sn.boxplot(x='neighbourhood_group', y='price', data=listing)
plt.title("Price Distribution by Neighbourhood Group")
plt.show()

# %%
sn.stripplot(x='neighbourhood_group', y='price', data=listing, jitter=True)
plt.title("Prices by Neighbourhood Group")
plt.show()
# Out:
# C:\Users\tebrick_KING\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\tebrick_KING\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
pivot_table = listing.pivot_table(index='neighbourhood_group', values='price', aggfunc='mean')
sn.heatmap(pivot_table, annot=True, cmap='coolwarm')
plt.title("Heatmap of Mean Prices by Neighbourhood Group")
plt.show()

# %%
sn.histplot(data=listing, x='price', hue='neighbourhood_group', kde=True)
plt.title("Price Distribution by Neighbourhood Group")
plt.show()
# Out:
# C:\Users\tebrick_KING\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
listing['neighbourhood_group'].value_counts().plot.pie(autopct='%1.1f%%', figsize=(6, 6))
plt.title("Proportion of Neighbourhood Groups")
plt.ylabel("")
plt.show()
